# %% [markdown]
# Разделение датасета по аномалиям\
# Нужная структура: \
# **[час, день недели, месяц, температура, влажность, total_AP_max]**

# %% [markdown]
# Трейн на всех:
# - + original
# - + original emd
# - + original multi
# - + original multi emd
# -
# - only_days
# - only_days emd
# - only_days multi
# - only_days multi emd
# -
# - windows
# - windows emd
# - windows multi
# - windows multi emd
#
# Трейн на норм
# - + original
# - + original emd
# - + original multi
# - + original multi emd
# -
# - only_days
# - only_days emd
# - only_days multi
# - only_days multi emd
# -
# - windows
# - windows emd
# - windows multi
# - windows multi emd

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.svm import OneClassSVM
from data_preparation import get_data_3 as get_data

# %%
# wind r'C:/Users/Lomonosova/Downloads/iqds.22.03/iqds/ds_electricity.csv'
# mac r'/Users/veronikalomonosova/Downloads/iqds/ds_electricity.csv'
path = r'/Users/veronikalomonosova/Downloads/iqds'
elec = pd.read_csv(path + '/ds_electricity.csv')
# Out:
# /Users/veronikalomonosova/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (9,10,11,12,13,16,24,25,26,27,28,31,39,40,41,42,43,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # ANOM_3
# ## OCSVM

# %%
anom = elec[elec.io_id == '5f33e3c7fb3bbc2c40fb6afe'].reset_index(drop=True)
anom.event_timestamp = pd.to_datetime(anom.event_timestamp, unit='s')
ind = 335773
before = 4
after = 7

# %%
anom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/47/5nlzntj579sc2tyzt4gzln1r0000gn/T/ipykernel_10228/2853152822.py in <module>
# ----> 1 anom
#
# NameError: name 'anom' is not defined

# %% [markdown]
# ### Оригинальные данные, одна размерность, без EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7] .reset_index(drop=True), \
              mode='original', emd=False, dimension='one')[1:, np.newaxis]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df)
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0]], color='red')

# %% [markdown]
# ### Оригинальные данные, одна размерность, с EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=True, dimension='one')[1:, np.newaxis]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df)
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0]], color='red')
# Out:
# [  48  766 1483 2201 2919 3639 4359 5078 5798 6518 7238 7954]
# 48
# 0 48
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/47/5nlzntj579sc2tyzt4gzln1r0000gn/T/ipykernel_7601/2562303340.py in <module>
# ----> 1 df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
#       2               mode='original', emd=True, dimension='one')[1:, np.newaxis]
#       3 nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
#       4 ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
#       5 ocsvm.fit(df)
#
# ~/Documents/GitHub/diploma/OCSVM/data_preparation.py in get_data(df, mode, emd, dimension, window_size)
#      44             #print(df.loc[prev:i])
#      45             print(prev, i)
# ---> 46             st = np.where(df['total_AP'][prev:i] > 0.5)[0][0] + prev
#      47             end = np.where(df['total_AP'].loc[prev:i] > 0.5)[0][len(np.where(df['total_AP'].loc[prev:i] > 0.5)[0]) - 1] + prev
#      48             emd = EMD()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ### Оригинальные данные, мульти размерность, без EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi')[1:]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %% [markdown]
# ### Оригинальные данные, мульти размерность, c EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi')[1:]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %% [markdown]
# ### Оригинальные данные, одна размерность, без EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='original', emd=False, dimension='one')[1:, np.newaxis]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=False, dimension='one')[1:, np.newaxis]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %%
df = get_data(anom.loc[335773 - 730 * 4:].reset_index(drop=True), \
              mode='original', emd=False, dimension='one')[1:, np.newaxis]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %% [markdown]
# ### Оригинальные данные, одна размерность, c EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='original', emd=True, dimension='one')[1:, np.newaxis]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=True, dimension='one')[1:, np.newaxis]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %%
df = get_data(anom.loc[335773 - 720 * 4:335773].reset_index(drop=True), \
              mode='original', emd=True, dimension='one')[1:, np.newaxis]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %% [markdown]
# ### Оригинальные данные, мульти размерность, без EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi')[1:]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi')[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi')[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %% [markdown]
# ### Оригинальные данные, мульти размерность, c EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi')[1:]
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi')[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi')[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.plot(np.arange(len(df)), df[:, 0])
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red')

# %% [markdown]
# ### Суточные данные, одна размерность, без EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=False, dimension='one')
df[0][0] = 0
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)#(, rows=5)

i = 0
for day in df:
    ocsvm.fit(day[:, np.newaxis])
    preds = ocsvm.predict(day[:, np.newaxis])
    #print(preds)

    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, одна размерность, с EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=True, dimension='one')
df[0][0] = 0
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)#(, rows=5)
print(df.shape)
i = 0
for day in df:
    ocsvm.fit(day[:, np.newaxis])
    preds = ocsvm.predict(day[:, np.newaxis])
    #print(preds)

    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, мульти размерность, без EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi')
df[0][0] = np.zeros(len(df[0][0]))
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)#(, rows=5)
print(df.shape)
i = 0
for day in df:
    ocsvm.fit(day)
    preds = ocsvm.predict(day)
    #print(preds)

    ax[i].plot(np.arange(len(day)), day[:, 0])
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]][:, 0], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, мульти размерность, с EMD
# Трейн на всех

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi')
df[0][0] = np.zeros(len(df[0][0]))
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)#(, rows=5)
print(df.shape)
i = 0
for day in df:
    ocsvm.fit(day)
    preds = ocsvm.predict(day)
    #print(preds)

    ax[i].plot(np.arange(len(day)), day[:, 0])
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]][:, 0], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, одна размерность, без EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='windows', emd=False, dimension='one')
df[0][0] = 0
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

#(, rows=5)
print(df.shape)
i = 0
for day in df:
    ocsvm.fit(day[:, np.newaxis])
    
    #print(preds)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=False, dimension='one')
df[0][0] = 0
fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)
for day in df:
    preds = ocsvm.predict(day[:, np.newaxis])
    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='windows', emd=False, dimension='one')
df[0][0] = 0
fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)
i =0
for day in df:
    preds = ocsvm.predict(day[:, np.newaxis])
    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, одна размерность, с EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='windows', emd=True, dimension='one')
df[0][0] = 0
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

#(, rows=5)
print(df.shape)
i = 0
for day in df:
    ocsvm.fit(day[:, np.newaxis])
    preds = ocsvm.predict(day[:, np.newaxis])
    #print(preds)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=True, dimension='one')
df[0][0] = 0
fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)
for day in df:
    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='windows', emd=True, dimension='one')
df[0][0] = 0
fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)
i =0
for day in df:
    preds = ocsvm.predict(day[:, np.newaxis])
    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, мульти размерность, без EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:335773].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi')
df[0][0] = np.zeros(len(df[0][0]))
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

i = 0
for day in df:
    ocsvm.fit(day)
    
    #print(preds)

df = get_data(anom.loc[335773 - 720 * 2:335773 + 720 * 2].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi')
df[0][0] = 0
fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)
for day in df:
    preds = ocsvm.predict(day)
    ax[i].plot(np.arange(len(day)), day[:, 0])
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0], 0], color='red')
    i += 1

# %% [markdown]
# ### Суточные данные, мульти размерность, с EMD
# Трейн на норм

# %%
df = get_data(anom.loc[335773 - 730 * 4:].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi')
df[0][0] = np.zeros(len(df[0][0]))
nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}

i = 0
for day in df:
    ocsvm.fit(day)
    preds = ocsvm.predict(day)
    #print(preds)

df = get_data(anom.loc[335773:335773 + 720 * 7].reset_index(drop=True), \
              mode='windows', emd=True, dimension='one')
df[0][0] = 0
fig, ax = plt.subplots(figsize=(12, 30), nrows=len(df), ncols=1)
for day in df:
    ax[i].plot(np.arange(len(day)), day)
    ax[i].scatter(np.where(preds == -1)[0], day[np.where(preds == -1)[0]], color='red')
    i += 1
# Out:
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:318: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AP[i] = AP[i - 1]
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 3639
# 2919 3639
# 3095 3639 4
# 4359
# 3639 4359
# 3639 4250 5
# 5078
# 4359 5078
# 4535 4969 6
# 5798
# 5078 5798
# 5254 5689 7
# 6518
# 5798 6518
# 5974 6409 8
# 7238
# 6518 7238
# 6694 7129 9
# 7954
# 7238 7954
# 7414 7845 10
# 8674
# 7954 8674
# 8123 8565 11
# 9394
# 8674 9394
# 8851 9285 12
# 10114
# 9394 10114
# 9563 10005 13
# 10832
# 10114 10832
# 10283 10741 14
# 11552
# 10832 11552
# 11008 11458 15
# 12272
# 11552 12272
# 11728 12163 16
# 12991
# 12272 12991
# 12449 12883 17
# 13710
# 12991 13710
# 13163 13647 18
# 14430
# 13710 14430
# 13882 14354 19
# 15150
# 14430 15150
# 14603 15090 20
# 15870
# 15150 15870
# 15322 15762 21
# 16590
# 15870 16590
# 16041 16482 22
# 17310
# 16590 17310
# 16767 17202 23
# 18030
# 17310 18030
# 17487 17922 24
# 18750
# 18030 18750
# 18207 18642 25
# 19470
# 18750 19470
# 18927 19362 26
# 20190
# 19470 20190
# 19647 20082 27
# 20910
# 20190 20910
# 20367 20809 28
# 21630
# 20910 21630
# 21087 21522 29
# 22350
# 21630 22350
# 21806 22350 30
# 23070
# 22350 23070
# 22350 22949 31
# 23790
# 23070 23790
# 23243 23682 32
# 24510
# 23790 24510
# 23962 24402 33
# 25230
# 24510 25230
# 24682 25122 34
# 25950
# 25230 25950
# 25402 25842 35
# 26670
# 25950 26670
# 26122 26562 36
# 27390
# 26670 27390
# 26847 27282 37
# 28110
# 27390 28110
# 27567 28002 38
# 28830
# 28110 28830
# 28285 28728 39
# 29550
# 28830 29550
# 29007 29442 40
# 30270
# 29550 30270
# 29727 30170 41
# 30990
# 30270 30990
# 30447 30882 42
# 31710
# 30990 31710
# 31162 31604 43
# 32430
# 31710 32430
# 31881 32322 44
# 33150
# 32430 33150
# 32601 33051 45
# 33870
# 33150 33870
# 33327 33762 46
# 34590
# 33870 34590
# 34047 34482 47
# 35310
# 34590 35310
# 34767 35209 48
# 36030
# 35310 36030
# 35481 35922 49
# 36750
# 36030 36750
# 36201 36642 50
# 37471
# 36750 37471
# 36927 37362 51
# 38191
# 37471 38191
# 37643 38083 52
# 38911
# 38191 38911
# 38366 38803 53
# 39631
# 38911 39631
# 39081 39523 54
# 40351
# 39631 40351
# 39808 40251 55
# 41072
# 40351 41072
# 40528 40963 56
# 41792
# 41072 41792
# 41248 41683 57
# 42512
# 41792 42512
# 41968 42403 58
# 43231
# 42512 43231
# 42688 43143 59
# 43951
# 43231 43951
# 43408 43850 60
# 44671
# 43951 44671
# 44128 44572 61
# 45391
# 44671 45391
# 44842 45282 62
# 46111
# 45391 46111
# 45562 46007 63
# 46831
# 46111 46831
# 46288 46729 64
# 47551
# 46831 47551
# 47007 47478 65
# 48271
# 47551 48271
# 47722 48171 66
# 48991
# 48271 48991
# 48442 48890 67
# 49711
# 48991 49711
# 49162 49612 68
# 50431
# 49711 50431
# 49884 50332 69
# 51151
# 50431 51151
# 50608 51051 70
# 51871
# 51151 51871
# 51328 51768 71
# 52588
# 51871 52588
# 52044 52487 72
# 53308
# 52588 53308
# 52764 53207 73
# 54028
# 53308 54028
# 53479 53919 74
# 54748
# 54028 54748
# 54198 54639 75
# 55468
# 54748 55468
# 54924 55359 76
# 56188
# 55468 56188
# 55644 56079 77
# 56908
# 56188 56908
# 56364 56799 78
# 57628
# 56908 57628
# 57084 57529 79
# 58347
# 57628 58347
# 57804 58113 80
# 59066
# 58347 59066
# 58565 58967 81
# 59786
# 59066 59786
# 59243 59677 82
# 60506
# 59786 60506
# 59963 60407 83
# 61226
# 60506 61226
# 60683 61125 84
# 61946
# 61226 61946
# 61403 61839 85
# 62666
# 61946 62666
# 62123 62557 86
# 63386
# 62666 63386
# 62843 63277 87
# 64106
# 63386 64106
# 63562 64007 88
# 64826
# 64106 64826
# 64282 64717 89
# 65546
# 64826 65546
# 65002 65437 90
# 66266
# 65546 66266
# 65723 66157 91
# 66986
# 66266 66986
# 66443 66877 92
# 67706
# 66986 67706
# 67163 67597 93
# 68426
# 67706 68426
# 67883 68317 94
# 69146
# 68426 69146
# 68603 69037 95
# 69866
# 69146 69866
# 69322 69757 96
# 70586
# 69866 70586
# 70042 70477 97
# 71306
# 70586 71306
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/47/5nlzntj579sc2tyzt4gzln1r0000gn/T/ipykernel_3048/2677893881.py in <module>
# ----> 1 df = get_data(anom.loc[335773 - 730 * 4:].reset_index(drop=True), \
#       2               mode='windows', emd=True, dimension='multi')
#       3 df[0][0] = np.zeros(len(df[0][0]))
#       4 nu = 0.05  # theory says it should be an upper bound of the fraction of outliers
#       5 ocsvm = OneClassSVM(kernel='linear', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
#
# ~/Documents/GitHub/diploma/OCSVM/data_preparation.py in get_data_3(df, mode, emd, dimension, window_size)
#     332             #print(df.loc[prev:i])
#     333             print(prev, i)
# --> 334             st = np.where(df['total_AP'][prev:i] > 0.5)[0][0] + prev
#     335             end = np.where(df['total_AP'].loc[prev:i] > 0.5)[0][len(np.where(df['total_AP'].loc[prev:i] > 0.5)[0]) - 1] + prev
#     336             emd = EMD()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ### Оригинальные данные, бинарная мульти размерность, без EMD (интервал 2)
# Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi_intervals', intervals=2)[1:]

nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi_intervals', intervals=2)[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red', zorder=1)
plt.plot(np.arange(len(df)), df[:, 0], zorder=0)

# %% [markdown]
# ### Оригинальные данные, бинарная мульти размерность, без EMD (интервал 5)
# Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi_intervals', intervals=5)[1:]

nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi_intervals', intervals=5)[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red', zorder=1)
plt.plot(np.arange(len(df)), df[:, 0], zorder=0)

# %% [markdown]
# ### Оригинальные данные, бинарная мульти размерность, без EMD (интервал 15)
# Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi_intervals', intervals=15)[1:]

nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=False, dimension='multi_intervals', intervals=15)[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red', zorder=1)
plt.plot(np.arange(len(df)), df[:, 0], zorder=0)

# %% [markdown]
# ### Оригинальные данные, бинарная мульти размерность, c EMD (интервал 2)
# Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi_intervals', intervals=2)[1:]

nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi_intervals', intervals=2)[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red', zorder=1)
plt.plot(np.arange(len(df)), df[:, 0], zorder=0)
# Out:
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 3639
# 2919 3639
# 3095 3639 4
# 4359
# 3639 4359
# 3639 4250 5
# 5078
# 4359 5078
# 4535 4969 6
# 5798
# 5078 5798
# 5254 5689 7
# 6518
# 5798 6518
# 5974 6409 8
# 7238
# 6518 7238
# 6694 7129 9
# 7954
# 7238 7954
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 7414 7845 10

# %% [markdown]
# ### Оригинальные данные, бинарная мульти размерность, c EMD (интервал 5)
# Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi_intervals', intervals=5)[1:]
print(df.shape)
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi_intervals', intervals=5)[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red', zorder=1)
plt.plot(np.arange(len(df)), df[:, 0], zorder=0)
# Out:
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# (2920, 44)
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 3639
# 2919 3639
# 3095 3639 4
# 4359
# 3639 4359
# 3639 4250 5
# 5078
# 4359 5078
# 4535 4969 6
# 5798
# 5078 5798
# 5254 5689 7
# 6518
# 5798 6518
# 5974 6409 8
# 7238
# 6518 7238
# 6694 7129 9
# 7954
# 7238 7954
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 7414 7845 10

# %% [markdown]
# ### Оригинальные данные, бинарная мульти размерность, c EMD (интервал 15)
# Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi_intervals', intervals=15)[1:]

nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)

df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=True, dimension='multi_intervals', intervals=15)[1:]
preds = ocsvm.predict(df)
plt.figure(figsize=(12, 8))
plt.scatter(np.where(preds == -1)[0], df[np.where(preds == -1)[0], 0], color='red', zorder=1)
plt.plot(np.arange(len(df)), df[:, 0], zorder=0)
# Out:
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 3639
# 2919 3639
# 3095 3639 4
# 4359
# 3639 4359
# 3639 4250 5
# 5078
# 4359 5078
# 4535 4969 6
# 5798
# 5078 5798
# 5254 5689 7
# 6518
# 5798 6518
# 5974 6409 8
# 7238
# 6518 7238
# 6694 7129 9
# 7954
# 7238 7954
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 7414 7845 10

# %%
### Суточные данные, бинарная мульти размерность, no EMD (интервал 2)
Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi_intervals', intervals=2)#[1:]
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
print(df)
ocsvm.fit(df)
df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi_intervals', intervals=2)#[1:]
preds = ocsvm.predict(df)
data = []
for i in df:
    data += i[:720].tolist()
data = np.array(data)
plt.figure(figsize=(12, 8))
data = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=False, dimension='one', intervals=2)
plt.plot(np.arange(len(data)), data, zorder=0)
for i in range(len(preds)):
    if preds[i] != 1:
        plt.plot(np.arange(i * 720, (i + 1)*720), data[i * 720: (i + 1)*720], zorder=0, color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/47/5nlzntj579sc2tyzt4gzln1r0000gn/T/ipykernel_10228/4131579936.py in <module>
# ----> 1 df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
#       2               mode='windows', emd=False, dimension='multi_intervals', intervals=2)#[1:]
#       3 nu=0.05
#       4 ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
#       5 print(df)
#
# TypeError: get_data_3() got an unexpected keyword argument 'intervals'

# %%
### Суточные данные, бинарная мульти размерность, no EMD (интервал 5)
Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi_intervals', intervals=5)#[1:]
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi_intervals', intervals=5)#[1:]
preds = ocsvm.predict(df)
data = []
for i in df:
    data += i[:720].tolist()
data = np.array(data)
plt.figure(figsize=(12, 8))
data = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=False, dimension='one', intervals=2)
plt.plot(np.arange(len(data)), data, zorder=0)
for i in range(len(preds)):
    if preds[i] != 1:
        plt.plot(np.arange(i * 720, (i + 1)*720), data[i * 720: (i + 1)*720], zorder=0, color='red')

# %%
### Суточные данные, бинарная мульти размерность, no EMD (интервал 15)
Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi_intervals', intervals=15)#[1:]
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='windows', emd=False, dimension='multi_intervals', intervals=15)#[1:]
preds = ocsvm.predict(df)
data = []
for i in df:
    data += i[:720].tolist()
data = np.array(data)
plt.figure(figsize=(12, 8))
data = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=False, dimension='one', intervals=2)
plt.plot(np.arange(len(data)), data, zorder=0)
for i in range(len(preds)):
    if preds[i] != 1:
        plt.plot(np.arange(i * 720, (i + 1)*720), data[i * 720: (i + 1)*720], zorder=0, color='red')

# %%
### Суточные данные, бинарная мульти размерность, с EMD (интервал 2)
Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi_intervals', intervals=2)#[1:]
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi_intervals', intervals=2)#[1:]
preds = ocsvm.predict(df)
data = []
for i in df:
    data += i[:720].tolist()
data = np.array(data)
plt.figure(figsize=(12, 8))
data = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=True, dimension='one', intervals=2)
plt.plot(np.arange(len(data)), data, zorder=0)
for i in range(len(preds)):
    if preds[i] != 1:
        plt.plot(np.arange(i * 720, (i + 1)*720), data[i * 720: (i + 1)*720], zorder=0, color='red')

# %%
### Суточные данные, бинарная мульти размерность, с EMD (интервал 5)
Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi_intervals', intervals=5)#[1:]
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi_intervals', intervals=5)#[1:]
preds = ocsvm.predict(df)
data = []
for i in df:
    data += i[:720].tolist()
data = np.array(data)
plt.figure(figsize=(12, 8))
data = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=True, dimension='one', intervals=2)
plt.plot(np.arange(len(data)), data, zorder=0)
for i in range(len(preds)):
    if preds[i] != 1:
        plt.plot(np.arange(i * 720, (i + 1)*720), data[i * 720: (i + 1)*720], zorder=0, color='red')

# %%
### Суточные данные, бинарная мульти размерность, с EMD (интервал 15)
Трейн на норм

# %%
df = get_data(anom.loc[ind - 730 * before:ind].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi_intervals', intervals=15)#[1:]
nu=0.05
ocsvm = OneClassSVM(kernel='rbf', gamma=0.05, nu=nu) # {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
ocsvm.fit(df)
df = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='windows', emd=True, dimension='multi_intervals', intervals=15)#[1:]
preds = ocsvm.predict(df)
data = []
for i in df:
    data += i[:720].tolist()
data = np.array(data)
plt.figure(figsize=(12, 8))
data = get_data(anom.loc[ind - 730 * before:ind + 720 * after].reset_index(drop=True), \
              mode='original', emd=True, dimension='one', intervals=2)
plt.plot(np.arange(len(data)), data, zorder=0)
for i in range(len(preds)):
    if preds[i] != 1:
        plt.plot(np.arange(i * 720, (i + 1)*720), data[i * 720: (i + 1)*720], zorder=0, color='red')
# Out:
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# [  48  766 1483 2201 2919]
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:511: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:511: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 3639
# 2919 3639
# 3095 3639 4
# 4359
# 3639 4359
# 3639 4250 5
# 5078
# 4359 5078
# 4535 4969 6
# 5798
# 5078 5798
# 5254 5689 7
# 6518
# 5798 6518
# 5974 6409 8
# 7238
# 6518 7238
# 6694 7129 9
# 7954
# 7238 7954
# 7414 7845 10
# [  48  766 1483 2201 2919 3639 4359 5078 5798 6518 7238 7954]
# 766
# 0 766
# 222 657 0
# 1483
# 766 1483
# 940 1375 1
# 2201
# 1483 2201
# 1658 2095 2
# 2919
# 2201 2919
# 2375 2810 3
# 3639
# 2919 3639
# 3095 3639 4
# 4359
# 3639 4359
# 3639 4250 5
# 5078
# 4359 5078
# 4535 4969 6
# 5798
# 5078 5798
# 5254 5689 7
# 6518
# 5798 6518
# 5974 6409 8
# 7238
# 6518 7238
# 6694 7129 9
# 7954
# 7238 7954
# /Users/veronikalomonosova/Documents/GitHub/diploma/OCSVM/data_preparation.py:511: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_AP'][st:end] = imfs[2] + df['total_AP'][st:end].mean()
# 7414 7845 10
